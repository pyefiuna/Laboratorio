# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/forestfires - forestfires.csv')
dfdrop=df
dfdrop.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2   NaN   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7    NaN  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
dfdrop=dfdrop.fillna({"DMC":5,"DC":8})
dfdrop
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2    5.0   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7    8.0   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df[["month","DMC"]]
# Out:
#     month    DMC
# 0     mar    NaN
# 1     oct   35.4
# 2     oct   43.7
# 3     mar   33.3
# 4     mar   51.3
# ..    ...    ...
# 512   aug   56.7
# 513   aug   56.7
# 514   aug   56.7
# 515   aug  146.0
# 516   nov    3.0
#
# [517 rows x 2 columns]

# %%
df.loc[[1,4,7],["FFMC","DC"]]
# Out:
#    FFMC     DC
# 1  90.6  669.1
# 4  89.3  102.2
# 7  91.5  608.2

# %%
df[df["day"].str.contains("mon")]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain    area
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0    0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0    0.00
# 13   6  5   sep  mon  90.9  126.5  686.5   7.0  21.3  42   2.2   0.0    0.00
# 17   8  5   oct  mon  84.9   32.8  664.2   3.0  16.7  47   4.9   0.0    0.00
# 21   5  4   sep  mon  91.8   78.5  724.3   9.2  19.1  38   2.7   0.0    0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...     ...
# 472  8  3   jun  mon  88.2   96.2  229.0   4.7  14.3  79   4.0   0.0    1.94
# 479  7  4   jul  mon  89.2  103.9  431.6   6.4  22.6  57   4.9   0.0  278.53
# 485  2  4   aug  mon  95.0  135.5  596.3  21.3  30.6  28   3.6   0.0    2.07
# 495  6  6   aug  mon  96.2  175.5  661.8  16.8  23.9  42   2.2   0.0    0.00
# 496  4  5   aug  mon  96.2  175.5  661.8  16.8  32.6  26   3.1   0.0    2.77
#
# [74 rows x 13 columns]

# %%
DF2=df.groupby("month").agg({
    "FFMC":"mean",
    "FFMC":"max",
    "DC":"sum"
})
DF2
# Out:
#        FFMC        DC
# month
# apr    91.0     437.0
# aug    96.2  117958.3
# dec    85.4    3161.2
# feb    86.9    1093.4
# jan    82.1     180.7
# jul    94.6   14419.3
# jun    94.3    5061.0
# mar    93.4    4100.9
# may    89.6     187.5
# nov    79.5     106.7
# oct    92.6    9538.2
# sep    94.3  126353.9

# %%
DF2.plot(kind="scatter",x="FFMC",y="DMC")
plt.show()

# %%
DF2.to_csv("Final.csv")
